# %% [markdown]
# # Adaptive Cognitive Budgeting (ACB) Demo
#
# This notebook runs the ACB Gradio Demo on Google Colab's free CPU tier.
#
# **Instructions:**
# 1. Go to **Runtime -> Run all** (or press `Ctrl+F9`).
# 2. Scroll to the bottom of the notebook.
# 3. Click the **public Gradio URL** (e.g., `https://xxxx.gradio.live`) to open the Web UI.

# %%
# !git clone https://github.com/SaiDheeraj-19/Adaptive-Cognitive-Budgeting-GPU-Free-LLMs.git
# %cd Adaptive-Cognitive-Budgeting-GPU-Free-LLMs/hf-demo
# !pip install -r requirements.txt

# %%
import sys
# Modify the app to launch with a public URL
with open('app.py', 'r') as f:
    app_code = f.read()
app_code = app_code.replace('demo.launch()', 'demo.launch(share=True, debug=True)')
with open('app.py', 'w') as f:
    f.write(app_code)

# !python app.py
